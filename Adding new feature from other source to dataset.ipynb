# %%
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#    year     make     model        trim   body transmission                vin  \
# 0  2002     Ford    Escort  ZX2 Deluxe  coupe          NaN  3fafp11362r198421
# 1  2003   Nissan    Altima      2.5 SL  Sedan    automatic  1n4al11d93c243639
# 2  2009      NaN       NaN         NaN    NaN    automatic  2fahp71v99x109403
# 3  2000  Hyundai    Sonata         GLS  Sedan    automatic  kmhwf35v1ya261203
# 4  1999   Saturn  S-Series         SL2  Sedan    automatic  1g8zk5275xz237091
#
#   state  condition  odometer   color interior  \
# 0    pa        1.9  164660.0  silver     gray
# 1    hi        1.4  101792.0   white     gray
# 2    fl        2.0       1.0   white     gray
# 3    nc        1.9  191954.0   green      tan
# 4    wa        2.0  171652.0   white     gray
#
#                                   seller   mmr  sellingprice  \
# 0                      hertz remarketing   725           100
# 1  credit acceptance corp/vrs/southfield  2950           100
# ...

# %%
df.make=df.make.str.upper()
df.make.nunique()
# Out:
# 57

# %%
df2
# Out:
#        No.           Company         Origin
# 0      1.0            Abarth          Italy
# 1      2.0             Acura          Japan
# 2      3.0            Aiways          China
# 3      4.0        Alfa Romeo          Italy
# 4      5.0           Aprilia          Italy
# ..     ...               ...            ...
# 148  147.0             XPeng          China
# 149  148.0            Yamaha          Japan
# 150  149.0   Zero Motorcycle  United States
# 151  150.0  Zenvo Automotive        Denmark
# 152  151.0     Zündapp Janus        Germany
#
# [153 rows x 3 columns]

# %%
# prepare for inner join

df2.Company = df2.Company.str.upper()
df2.rename(columns={"Company": "make"},inplace=True)

# %%
new_df = df.merge(df2, how='inner', on='make')
new_df
# Out:
#         year         make       model        trim         body transmission  \
# 0       2002         FORD      Escort  ZX2 Deluxe        coupe          NaN
# 1       1997         FORD      Taurus           G        Sedan    automatic
# 2       2006         FORD       F-150         XLT     SuperCab    automatic
# 3       2001         FORD      Taurus         SES        Sedan    automatic
# 4       2001         FORD       Focus         ZX3    Hatchback          NaN
# ...      ...          ...         ...         ...          ...          ...
# 103501  2005      FERRARI        F430        Base        coupe          NaN
# 103502  2010      FERRARI  California        Base  Convertible    automatic
# 103503  2011  ROLLS-ROYCE       Ghost        Base        Sedan    automatic
# 103504  2012  ROLLS-ROYCE       Ghost         EWB        sedan    automatic
# 103505  2012  ROLLS-ROYCE       Ghost        Base        Sedan    automatic
#
# ...

# %%
new_df[['make','Origin']]
# Out:
#                make          Origin
# 0              FORD   United States
# 1              FORD   United States
# 2              FORD   United States
# 3              FORD   United States
# 4              FORD   United States
# ...             ...             ...
# 103501      FERRARI           Italy
# 103502      FERRARI           Italy
# 103503  ROLLS-ROYCE  United Kingdom
# 103504  ROLLS-ROYCE  United Kingdom
# 103505  ROLLS-ROYCE  United Kingdom
#
# [103506 rows x 2 columns]

# %%
new_df.make.nunique()
# Out:
# 32
